# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib as mp
import plotly.express as px

# %%
movies_df=pd.read_csv('tmdb_5000_movies.csv',delimiter=',')
credits_df=pd.read_csv('tmdb_5000_credits.csv',delimiter=',')

# %%
movies_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
#merging data frames
movies = movies_df.merge(credits_df, on='title')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.loc[:,'original_language'].value_counts() #not balanced
# Out:
# original_language
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: count, dtype: int64

# %%
#choosing required columns - for possible tagging
movie=movies[['genres','id','keywords','title','overview','cast','crew']]
movie.head()
# Out:
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
#creating a tags col = genres+keywords+cast(main)+crew(onlydirector)
movie.isnull().sum()   #overview has 3 cols as null , dropping the 3 cols
# Out:
# genres      0
# id          0
# keywords    0
# title       0
# overview    3
# cast        0
# crew        0
# dtype: int64

# %%
movie.dropna(inplace=True)
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/4265595405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie.dropna(inplace=True)

# %%
movie.isnull().sum()
# Out:
# genres      0
# id          0
# keywords    0
# title       0
# overview    0
# cast        0
# crew        0
# dtype: int64

# %%
#checking duplication
movie.duplicated().sum()
# Out:
# 0

# %%
movie.loc[0,'genres']
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#genre lister
def genre_lister(object):
    import ast
    object=ast.literal_eval(object) #list is stored as string, converting String Representation of a List
    list_genre=[]
    for i in object:
        list_genre.append(i['name'])
    return list_genre

# %%
movie['genres']=movie['genres'].apply(genre_lister)
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/822554694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['genres']=movie['genres'].apply(genre_lister)

# %%
movie.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movie['keywords']=movie['keywords'].apply(genre_lister)
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/4020725540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['keywords']=movie['keywords'].apply(genre_lister)

# %%
movie.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
#top 3 actors
def cc_lister(object):
    import ast
    object=ast.literal_eval(object) #list is stored as string, converting String Representation of a List
    list_cc=[]
    for i in object:
        list_cc.append(i['name'])
    return list_cc[:3] #taking top 3

# %%
print(cc_lister(movie.loc[0,'cast']))
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver']

# %%
movie['cast']=movie['cast'].apply(cc_lister)
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/2532267407.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['cast']=movie['cast'].apply(cc_lister)

# %%
movie.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movie.loc[0,'crew']
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
def director(object):
    import ast
    object=ast.literal_eval(object) #list is stored as string, converting String Representation of a List
    director=[]
    for i in object:
        if i['job'] == "Director":
            director.append(i['name'])
    return director

# %%
print(director(movie.loc[0,'crew']))
# Out:
# ['James Cameron']

# %%
movie['crew']=movie['crew'].apply(director)
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/2352932875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['crew']=movie['crew'].apply(director)

# %%
movie.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
def stringcleaner(string):
    if isinstance(string, str): #checking if string
        string=string.replace(","," ")
        string=string.replace("?"," ")
        string=string.replace("."," ")
        string=string.replace("!"," ")
        return string.split()
    else:
        return []

# %%
print(stringcleaner(movie.loc[0,'overview']))
# Out:
# ['In', 'the', '22nd', 'century', 'a', 'paraplegic', 'Marine', 'is', 'dispatched', 'to', 'the', 'moon', 'Pandora', 'on', 'a', 'unique', 'mission', 'but', 'becomes', 'torn', 'between', 'following', 'orders', 'and', 'protecting', 'an', 'alien', 'civilization']

# %%
movie['overview']=movie['overview'].apply(stringcleaner)
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/3571058506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['overview']=movie['overview'].apply(stringcleaner)

# %%
movie.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movie['genres']=movie['genres'].apply(lambda x : [i.replace(" ","") for i in x])
movie['keywords']=movie['keywords'].apply(lambda x : [i.replace(" ","") for i in x])
movie['cast']=movie['cast'].apply(lambda x : [i.replace(" ","") for i in x])
movie['crew']=movie['crew'].apply(lambda x : [i.replace(" ","") for i in x])
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/1261793238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['genres']=movie['genres'].apply(lambda x : [i.replace(" ","") for i in x])
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/1261793238.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['keywords']=movie['keywords'].apply(lambda x : [i.replace(" ","") for i in x])
# ...

# %%
movie.head()
# Out:
#                                          genres      id  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1                  [Adventure, Fantasy, Action]     285
# 2                    [Action, Adventure, Crime]  206647
# 3              [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, ScienceFiction]   49529
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movie['tags']=movie['genres']+movie['keywords']+movie['cast']+movie['crew']+movie['overview']
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/4045545335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['tags']=movie['genres']+movie['keywords']+movie['cast']+movie['crew']+movie['overview']

# %%
movie.head()
# Out:
#                                          genres      id  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1                  [Adventure, Fantasy, Action]     285
# 2                    [Action, Adventure, Crime]  206647
# 3              [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, ScienceFiction]   49529
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movie_df=movie[['id','title','tags']]

# %%
movie_df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     [Action, Adventure, Fantasy, ScienceFiction, c...
# 1     [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2     [Action, Adventure, Crime, spy, basedonnovel, ...
# 3     [Action, Crime, Drama, Thriller, dccomics, cri...
# ...

# %%
movie_df.loc[0]['tags']
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'ScienceFiction',
#  'cultureclash',
#  'future',
#  'spacewar',
#  'spacecolony',
#  'society',
#  'spacetravel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alienplanet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'loveaffair',
#  'antiwar',
#  'powerrelations',
#  'mindandsoul',
#  '3d',
#  'SamWorthington',
#  'ZoeSaldana',
#  'SigourneyWeaver',
#  'JamesCameron',
#  'In',
#  'the',
#  '22nd',
#  'century',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization']

# %%
import numpy as np

movie_df['tags'] = movie_df['tags'].apply(lambda tag_list: list(np.char.lower(np.array(tag_list))))
movie_df['tags'] = movie_df['tags'].apply(lambda tag_list: " ".join(tag_list))
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/3051802404.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['tags'] = movie_df['tags'].apply(lambda tag_list: list(np.char.lower(np.array(tag_list))))
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/3051802404.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['tags'] = movie_df['tags'].apply(lambda tag_list: " ".join(tag_list))

# %%
movie_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drugabuse exoti...
# 2  action adventure crime spy basedonnovel secret...
# 3  action crime drama thriller dccomics crimefigh...
# 4  action adventure sciencefiction basedonnovel m...

# %%
#test vectorization 
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words="english") 
#fitting and converting to numpyarray
vectors = cv.fit_transform(movie_df['tags']).toarray()

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       dtype=object)

# %%
pip install nltk
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()   #going to stem the text for word variations (actor, actors etc)

# %%
#function to stem 
def stemmer(string):
    res=[]
    n=string.split()
    for i in n:
        res.append(ps.stem(i))
    
    return " ".join(res)

# %%
stemmer(movie_df['tags'].loc[6])
# Out:
# "anim famili hostag magic hors fairytal music princess anim tower blondewoman selfish healingpow basedonfairytal duringcreditssting healinggift animalsidekick zacharylevi mandymoor donnamurphi byronhoward nathangreno when the kingdom' most wanted-and most charming-bandit flynn rider hide out in a mysteri tower he' taken hostag by rapunzel a beauti and feisti tower-bound teen with 70 feet of magic golden hair flynn' curiou captor who' look for her ticket out of the tower where she' been lock away for year strike a deal with the handsom thief and the unlik duo set off on an action-pack escapad complet with a super-cop hors an over-protect chameleon and a gruff gang of pub thug"

# %%
movie_df['tags']= movie_df['tags'].apply(stemmer)
# Out:
# /var/folders/px/drmwszwx3g3b3qrz5_6shf5w0000gn/T/ipykernel_6947/4068603882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['tags']= movie_df['tags'].apply(stemmer)

# %%
#test vectorization 
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words="english") 
#fitting and converting to numpyarray
vectors = cv.fit_transform(movie_df['tags']).toarray()

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       dtype=object)

# %%
#cosine distance between vectors  - the lesser the angle theta more similar the vectors -- cosine similarity (0 no 1 same)/ cosine distance

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity =  cosine_similarity(vectors)    #similarity matrix

# %%
#for the first movie
similarity[0]    #diagonal 1 as movie getting compared to itself
# Out:
# array([1.        , 0.08238526, 0.08492078, ..., 0.06477503, 0.02242243,
#        0.        ])

# %%
def recommend(movie):
    #fetching index of movie
    movie_index=movie_df[movie_df["title"]==movie].index[0] #index at 0th col
    distances=similarity[movie_index]
    #sorting using index+similarity from each element
    movielist=sorted(list(enumerate(distances)),reverse=True, key=lambda x:x[1])[1:6]  #top 5 most similar
    for i in movielist:
        print(movie_df.loc[i[0]].title) #title for each index

# %%
recommend("Scream")
# Out:
# Cat People
# Scream 3
# Jennifer's Body
# My Soul to Take
# Young Frankenstein
